# %% [markdown]
# <a href="https://colab.research.google.com/github/kevin-blasiak-curtin/ISYS2001-Archive/blob/main/Module%2004%20-%20Going%20Loopy/week4_miniproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 4 Mini-Project: Loop-Powered Finance Tracker
#
# Last week your tracker could make a single decision. This week we add repetition, so it can take a series of expenses in one session, keep a running total, and report something useful about the spending.
#
# Expect this to take 45 to 60 minutes. It is your lab ticket for the week, so it is submitted and assessed pass or fail.

# %% [markdown]
# ## How to approach this ticket
#
# Write the loops yourself, and work through each problem before reaching for AI.
#
# This matters more than it might first appear. We spend a week on loops so the patterns become something you can produce from memory rather than something you retrieve from a chat window. If AI generates the whole thing, you are left with code that runs and very little understanding to show for it.
#
# So the approach for this ticket is:
#
# - Attempt each part yourself first. Getting it wrong and then correcting it is where most of the learning happens.
# - When you are genuinely stuck, use AI as a debugging and explaining partner rather than a code generator. Prompts that tend to help: "why does this while loop never terminate", "trace through this loop when the input is abc, then 5, then done", "this feels overcomplicated, show me the simplest version using only while, if, input and lists".
# - Do not prompt with "write me a finance tracker" and copy the result back. That defeats the purpose of the exercise, and it usually becomes clear when we discuss your code.
# - AI is confidently wrong on occasion. Recognising and correcting that is part of the work.
#
# Alongside the code, you keep a short reflection (near the bottom of this notebook) on how the work went. Record it as you go rather than reconstructing it at the end.

# %% [markdown]
# ## Part 1: Setup and expense entry
#
# Begin with the user setup, then allow the user to enter as many expenses as they like in one session.
#
# The budget validation below is provided as a worked pattern. Your task is the expense entry loop beneath it. Keep asking for expenses until the user types `done`, and for each valid amount, store it, add it to the running total, and give brief feedback.

# %%
print("=== Loop-Powered Finance Tracker ===")
print()

name = input("Enter your name: ")

# Budget validation, provided as a worked pattern.
# Keeps asking until the number falls within a sensible range.
monthly_budget = 0
while monthly_budget < 100 or monthly_budget > 10000:
    try:
        budget_input = input("Enter monthly budget ($100 to $10,000): $")
        monthly_budget = float(budget_input)
        if monthly_budget < 100:
            print("Budget too low. Minimum is $100.")
        elif monthly_budget > 10000:
            print("Budget seems high. Maximum is $10,000.")
    except ValueError:
        print("Please enter a valid number.")

print(f"\nWelcome {name}. Monthly budget: ${monthly_budget:.2f}")

# ===== Your task: multi-expense entry =====
expenses = []      # every amount is stored here
total_spent = 0

print("\n--- Enter your expenses ---")
print("Type 'done' when you are finished.")

while True:
    entry = input("\nExpense amount (or 'done'): $")

    if entry.lower() == "done":
        break

    try:
        amount = float(entry)
        if amount <= 0:
            print("Expense must be a positive number.")
        else:
            expenses.append(amount)
            total_spent += amount
            print(f"Added: ${amount:.2f}. Running total: ${total_spent:.2f}")
    except ValueError:
        print("Invalid input. Please enter a number or 'done'.")


print(f"\nEntry complete: {len(expenses)} expenses, ${total_spent:.2f} total")
# Out:
# === Loop-Powered Finance Tracker ===
#
# Enter your name: jo
# Enter monthly budget ($100 to $10,000): $done
# Please enter a valid number.
# Enter monthly budget ($100 to $10,000): $4000
#
# Welcome jo. Monthly budget: $4000.00
#
# --- Enter your expenses ---
# Type 'done' when you are finished.
#
# Expense amount (or 'done'): $done
#
# Entry complete: 0 expenses, $0.00 total

# %% [markdown]
# ## Part 2: Summarise the numbers
#
# You now have a list of expenses, so the next step is to summarise it. The total and average are provided. Your task is to find the highest and lowest values, and to count the large expenses.

# %%
if len(expenses) > 0:
    print("\n--- Analysis ---")
    average = total_spent / len(expenses)
    print(f"Total spent: ${total_spent:.2f}")
    print(f"Average expense: ${average:.2f}")
    print(f"Budget used: {(total_spent / monthly_budget) * 100:.1f}%")

    # Your task: find the highest and lowest expense.
    # Hint: start both at the first item, then loop and compare.
    highest = expenses[0]
    lowest = expenses[0]
    for expense in expenses:
        if expense > highest:
            highest = expense
        if expense < lowest:
            lowest = expense

    print(f"Highest expense: ${highest:.2f}")
    print(f"Lowest expense: ${lowest:.2f}")

    # Your task: count how many expenses were more than 20% of the budget.
    large_count = 0
    threshold = monthly_budget * 0.20
    for expense in expenses:
        if expense > threshold:
            large_count += 1

    print(f"Large expenses (over 20% of budget): {large_count}")

else:
    print("\nNo expenses entered, so there is nothing to analyse.")
# Out:
# --- Analysis ---
# Total spent: $1000.00
# Average expense: $333.33
# Budget used: 20.0%
# Highest expense: $500.00
# Lowest expense: $200.00
# Large expenses (over 20% of budget): 0

# %% [markdown]
# ## Part 3: A menu that keeps running
#
# Wrap the program in a menu so the user can keep working until they choose to quit. Option 4 (quit) is provided. Complete options 1, 2 and 3 using patterns from earlier in the notebook.

# %%
running = True

while running:
    print("\n" + "-" * 30)
    print(f"{name}'s finance tracker")
    print("-" * 30)
    print("1. View all expenses")
    print("2. View summary")
    print("3. Add an expense")
    print("4. Quit")

    choice = input("\nChoose an option (1-4): ")

    if choice == "1":
        if len(expenses) == 0:
            print("No expenses to display yet.")
        else:
            print("--- All Expenses ---")
            for i, expense_item in enumerate(expenses):
                print(f"{i+1}. ${expense_item:.2f}")

    elif choice == "2":
        if len(expenses) > 0:
            print("\n--- Analysis ---")
            average = total_spent / len(expenses)
            print(f"Total spent: ${total_spent:.2f}")
            print(f"Average expense: ${average:.2f}")
            print(f"Budget used: {(total_spent / monthly_budget) * 100:.1f}%")

            highest = expenses[0]
            lowest = expenses[0]
            for expense in expenses:
                if expense > highest:
                    highest = expense
                if expense < lowest:
                    lowest = expense

            print(f"Highest expense: ${highest:.2f}")
            print(f"Lowest expense: ${lowest:.2f}")

            large_count = 0
            threshold = monthly_budget * 0.20
            for expense in expenses:
                if expense > threshold:
                    large_count += 1

            print(f"Large expenses (over 20% of budget): {large_count}")

        else:
            print("\nNo expenses entered, so there is nothing to analyse.")

    elif choice == "3":
        while True:
            entry = input("\nExpense amount to add: $")
            try:
                amount = float(entry)
                if amount <= 0:
                    print("Expense must be a positive number.")
                else:
                    expenses.append(amount)
                    total_spent += amount
                    print(f"Added: ${amount:.2f}. Running total: ${total_spent:.2f}")
                    break # Exit the inner loop after a valid entry
            except ValueError:
                print("Invalid input. Please enter a number.")

    elif choice == "4":
        running = False
        print(f"\nGoodbye, {name}.")

    else:
        print("Not a valid choice. Please pick 1 to 4.")
# Out:
# ------------------------------
# jo's finance tracker
# ------------------------------
# 1. View all expenses
# 2. View summary
# 3. Add an expense
# 4. Quit
#
# Choose an option (1-4): 1
# --- All Expenses ---
# 1. $300.00
# 2. $200.00
# 3. $500.00
# 4. $560.00
#
# ------------------------------
# jo's finance tracker
# ------------------------------
# 1. View all expenses
# 2. View summary
# 3. Add an expense
# 4. Quit
#
# Choose an option (1-4): 3
#
# Expense amount to add: $-90
# Expense must be a positive number.
#
# Expense amount to add: $4
# Added: $4.00. Running total: $1564.00
#
# ------------------------------
# jo's finance tracker
# ------------------------------
# 1. View all expenses
# 2. View summary
# 3. Add an expense
# 4. Quit
#
# Choose an option (1-4): 4
#
# Goodbye, jo.

# %% [markdown]
# ## Stretch (optional)
#
# If you finish early, add a savings goals section. Ask how many goals the user wants to track (1 to 5), then use a `for` loop to collect a name and target for each, and report how much remains to be saved. This section is not assessed.

# %%
# Optional. Delete this cell if you are not using it.

# %% [markdown]
# ## Test before you submit
#
# Run your tracker with the scenario below and confirm the figures match. Then test it against awkward input: a word where a number is expected, a negative amount, and `done` entered immediately with no expenses. It should handle all of these without crashing.

# %%
test = """
Test scenario:

Name: your name
Budget: $2000

Expenses:
  450     (rent)
  67.50   (groceries)
  89.00   (petrol)
  done

Then use the menu:
  1. View all expenses  -> should list 3 expenses
  2. View summary       -> should show $606.50 total
  3. Add an expense: 25 -> total becomes $631.50
  4. Quit

Awkward input to test:
  - "abc" as an amount
  - -50 as an amount
  - "done" entered immediately with no expenses
"""
print(test)

# %% [markdown]
# ## Reflection
#
# This section carries as much weight as the code for this ticket. Complete it as you work rather than at the end.
#
# Write honestly. Grammar is not being assessed and there are no wrong answers. What I am looking for is evidence that you attempted the problem, met some difficulties, and worked through them.

# %%
"""
# Answer honestly. A sentence or two for each is enough.

# 1. Where did you get stuck, and what did you try before asking AI?
    I struggled with validating the input, it was initially slightly difficult
    to make that work but it worked in the end by asking AI how input validation
    works in python. I did find it annoying to structure the menu loop so I used
    AI's help to structure it for me.

# 2. What did you actually ask AI? Paste the prompt you used.
   I used a few specific prompts, such as:
   - "How is input validation done in Python? and how can do that in this program"
   - "Make me a structured menu table for this program that allows users to
      choose between viewing expenses, summaries, adding new expenses, and quitting."

# 3. What did you change afterwards, and did you understand why it worked?
   After receiving instructions, I directly implemented the required code for
   all the parts. I made changes to integrate input validation, if statements
   for menu navigation, and loops. I understood that the try catch blocks handled
   potential errors from user input, ensuring the program didn't crash, and the
   loops provided the necessary repetition I needed.

# 4. Was AI wrong or overcomplicated about anything? What did you do about it?
   No as the worksheet is relatively simple, the AI was able to help really well
   without over complicating the whole thing.

# 5. Which of the three loop patterns (counted, conditional, collection)
#    did this project use, and where?
   This code used conditional loops and collection loops.

   Conditional Loops (while loops):
      - Budget Validation Loop: while monthly_budget < 100 or monthly_budget > 10000:
        This loop continues as long as the budget input is out of a valid range.
      - Multi-Expense Entry Loop: while True: (Part 1), which breaks when the
        user types 'done'. This loop continues indefinitely until a specific
        condition is met.
      - Main Menu Loop: while running: (Part 3), which continues as long as the
        running flag is True.
      - Add Single Expense Loop: while True: (Part 3), which breaks after a
        valid expense is entered.

   Collection Loops (for loops):
      - Finding Highest/Lowest Expense: for expense in expenses: This loop
        iterates directly over each item in the expenses list to find the maximum
        and minimum values.
      - Counting Large Expenses: for expense in expenses: This loop iterates
        through the expenses list to check each expense against a threshold.
      - Displaying All Expenses: for i, expense_item in enumerate(expenses):
        This loop iterates through the expenses list, providing both the index
        and value for display.
"""

# %% [markdown]
# ## What a pass looks like
#
# You pass this ticket if:
#
# - Your tracker runs through the test scenario without crashing.
# - The loops are your own work. If we discuss your code, you can explain what each loop does and why.
# - Your reflection contains genuine detail.
#
# The tracker does not need to be elegant or elaborate.
#
# ## Submitting
#
# You have two options:
#
# 1. Upload the completed notebook to Blackboard, with both your code and your reflection filled in inside the file, or
# 2. Submit a link to your repository containing the completed notebook.
#
# Whichever route you choose, make sure the code and the reflection are both present in the notebook itself. The submission is due by the date on the unit outline, and the usual one-week grace applies. It is assessed pass or fail.
